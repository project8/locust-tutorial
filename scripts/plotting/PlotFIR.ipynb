# %%
import ROOT
# Out:
# Welcome to JupyROOT 6.18/00

# %%
from ROOT import gStyle

# %%
histFile = ROOT.TFile.Open("/tmp/locust-tutorial/output/FIRhisto.root","READ")

# %%
dataHisto1 = histFile.Get("Real")
dataHisto2 = histFile.Get("Imag")

# %%
c1 = ROOT.TCanvas("Title1","Title",800,600)
c2 = ROOT.TCanvas("Title2","Title",800,600)

# %%
c1.cd()
# Out:
# <ROOT.TCanvas object ("Title1") at 0x5edbc60>

# %%
dataHisto1.Draw()

# %%
c1.Draw()

# %%
dataHisto2 = histFile.Get("Imag")

# %%
c2.cd()
# Out:
# <ROOT.TCanvas object ("Title2") at 0x5eb4dd0>

# %%
dataHisto2.Draw()

# %%
c2.Draw()
