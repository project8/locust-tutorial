# %%
import ROOT
# Out:
# Welcome to JupyROOT 6.18/00

# %%
from ROOT import gStyle

# %%
gStyle.SetPadLeftMargin(0.15)

# %%
treeFile = ROOT.TFile.Open("/tmp/locust-tutorial/output/FieldLineSeed335Output.root","READ")

# %%
treeField = treeFile.Get("component_step_world_DATA")

# %%
c = ROOT.TCanvas("myCanvasName","The Canvas Title",800,600)

# %%
c.cd()
# Out:
# <ROOT.TCanvas object ("myCanvasName") at 0x48d42a0>

# %%
treeField.SetMarkerStyle(8)

# %%
treeField.SetMarkerSize(0.5)

# %%
treeField.Draw("magnetic_field_z:position_z")

# %%
c.Draw()
