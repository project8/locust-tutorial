# %%
import ROOT
# Out:
# Welcome to JupyROOT 6.18/00

# %%
histFile = ROOT.TFile.Open("/tmp/output/basic.root","READ")

# %%
dataHisto = histFile.Get("histPSD_2_0")

# %%
c = ROOT.TCanvas("myCanvasName","The Canvas Title",800,600)

# %%
c.cd()
# Out:
# <ROOT.TCanvas object ("myCanvasName") at 0x572f440>

# %%
dataHisto.Draw()

# %%
c.Draw()

# %%
145-50
# Out:
# 95
