# %%
import ROOT
# Out:
# Welcome to JupyROOT 6.18/00

# %%
ROOT.gStyle.SetOptStat(0)

# %%
histFile = ROOT.TFile.Open("/tmp/locust-tutorial/output/agg_basic.root","READ")

# %%
gridHisto = histFile.Get("histAggGridPower_2")

# %%
gridHisto.GetZaxis().SetTitle("Power (W)")

# %%
c = ROOT.TCanvas("Name","Title",800,600)

# %%
c.cd()
# Out:
# <ROOT.TCanvas object ("Name") at 0x5840f10>

# %%
c.SetLeftMargin(0.2)

# %%
c.SetRightMargin(0.2)

# %%
gridHisto.Draw("colz")

# %%
c.Draw()

# %%
c2 = ROOT.TCanvas("Name2","Title2",800,600)

# %%
c2.cd()
# Out:
# <ROOT.TCanvas object ("Name2") at 0x5aa6380>

# %%
psdHisto = histFile.Get("histAggChPS_2_12")

# %%
psdHisto.Draw()

# %%
c2.Draw()
