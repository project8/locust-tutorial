# %%
import ROOT
# Out:
# Welcome to JupyROOT 6.18/00

# %%
from ROOT import gStyle

# %%
histFile = ROOT.TFile.Open("/tmp/locust-tutorial/output/KatydidOutput_Angle90.00_Pos0.004.root","READ")

# %%
dataHisto = histFile.Get("PSDSpectrogram_0_0")

# %%
c1 = ROOT.TCanvas("myCanvasName","The Canvas Title",800,600)

# %%
c2 = ROOT.TCanvas("myWaterfallPlot","Track",800,600)

# %%
c1.cd()
# Out:
# <ROOT.TCanvas object ("myCanvasName") at 0x5f881a0>

# %%
dataHisto.Draw()

# %%
c1.Draw()

# %%
c2.cd()
# Out:
# <ROOT.TCanvas object ("myWaterfallPlot") at 0x5f87d40>

# %%
dataHisto.GetYaxis().SetRangeUser(138.e6,142.e6)

# %%
dataHisto.GetXaxis().SetRangeUser(0.,1.e-3)

# %%
gStyle.SetOptStat(0)

# %%
dataHisto.Draw("colz")

# %%
c2.Draw()
