# %%
import ROOT
# Out:
# Welcome to JupyROOT 6.18/00

# %%
ROOT.gStyle.SetOptStat(0)

# %%
histFile = ROOT.TFile.Open("/tmp/output/agg_basic.root","READ")

# %%
gridHisto = histFile.Get("histAggGridPower_2")

# %%
c = ROOT.TCanvas("Name","Title",800,600)

# %%
c.cd()
# Out:
# <ROOT.TCanvas object ("Name") at 0x4634390>

# %%
c.SetLeftMargin(0.2)

# %%
c.SetRightMargin(0.2)

# %%
gridHisto.Draw("colz")

# %%
c.Draw()

# %%
c2 = ROOT.TCanvas("Name2","Title2",800,600)

# %%
c2.cd()
# Out:
# <ROOT.TCanvas object ("Name2") at 0x4897a20>

# %%
psdHisto = histFile.Get("histAggChPS_2_12")

# %%
psdHisto.Draw()

# %%
c2.Draw()
