# %%
import ROOT
# Out:
# Welcome to JupyROOT 6.18/00

# %%
histFile = ROOT.TFile.Open("/locust_mc/cbuild/output/basic.root","READ")

# %%
dataHisto = histFile.Get("histTSReal_0_0")

# %%
c = ROOT.TCanvas("myTimeSeries","Time Series",800,600)

# %%
c.cd()
# Out:
# <ROOT.TCanvas object ("myTimeSeries") at 0x4f7af40>

# %%
dataHisto.Draw()

# %%
c.Draw()

# %%
c2 = ROOT.TCanvas("myTimeSeries2","Time Series",800,600)

# %%
c2.cd()
# Out:
# <ROOT.TCanvas object ("myTimeSeries2") at 0x5193070>

# %%
dataHisto.SetAxisRange(20.0e-6, 20.5e-6,"X")

# %%
dataHisto.Draw()

# %%
c2.Draw()
