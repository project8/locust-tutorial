# %%
import ROOT
# Out:
# Welcome to JupyROOT 6.18/00

# %%
from ROOT import gStyle

# %%
histFile = ROOT.TFile.Open("/tmp/locust-tutorial/output/ModeMapOutput.root","READ")

# %%
dataHisto = histFile.Get("TE22_Ey")

# %%
c1 = ROOT.TCanvas("myCanvasName","The Canvas Title",800,600)

# %%
c1.cd()
# Out:
# <ROOT.TCanvas object ("myCanvasName") at 0x498d670>

# %%
dataHisto.Draw("colz")

# %%
c1.Draw()
